# %% [markdown]
# <a href="https://colab.research.google.com/github/omid-sakaki-ghazvini/Educations/blob/main/%D9%85%D9%81%D8%A7%D9%87%DB%8C%D9%85_%D8%A7%D9%88%D9%84%DB%8C%D9%87_%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # نصب و راه اندازی آناکوندا

# %% [markdown]
# ابتدا از طریق سایت زیر فایل برنامه آناکوندا را دانلود و نصب میکنیم:
#
# https://www.anaconda.com/download/success

# %% [markdown]
# # معرفی ژوپیتر نوت بوک

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1831x963>

# %% [markdown]
# # پرکاربردترین تابع پایتون : **print**

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("سلام پایتون")
# Out:
# سلام پایتون

# %% [markdown]
# ## عملگرهای + - * / **

# %%
print(1 + 2)
# Out:
# 3

# %%
print(5 - 4)
# Out:
# 1

# %%
print(2 * 4)
# Out:
# 8

# %%
print(6 / 3)
# Out:
# 2.0

# %%
print(3 ** 2)
# Out:
# 9

# %% [markdown]
# ## اولویت بندی اجرای پرانتزها:

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %%
a = 4 + 5

print(a)
# Out:
# 9

# %%
a= 3-2
a
# Out:
# 1

# %%
my_var = 3

print(my_var)

my_var = 100

print(my_var)
# Out:
# 3
# 100

# %%
my_var = my_var + 3

print(my_var)
# Out:
# 103

# %% [markdown]
# ## type:

# %%
x = 14.5

print(type(x))
# Out:
# <class 'float'>

# %%
pi = 3.141592

print(type(pi))
# Out:
# <class 'float'>

# %%
z_one = True

print(type(z_one))
# Out:
# <class 'bool'>

# %%
1 < 2
# Out:
# True

# %%
z_three = (1 < 2)

print(type(z_three))
# Out:
# <class 'bool'>

# %%
z_four = (5 < 3)

print(type(z_four))
# Out:
# <class 'bool'>

# %%
5 < 3
# Out:
# False

# %%
z_five = not z_four

print(type(z_five))
# Out:
# <class 'bool'>

# %%
w = "Hello, Python!"

print(type(w))
# Out:
# <class 'str'>

# %%
len(w)
# Out:
# 14

# %%
a = "1.12321"

print(type(a))
# Out:
# <class 'str'>

# %%
b = float(a)

print(type(b))
# Out:
# <class 'float'>

# %%
new_string = "abc" + "def"
print(new_string)
print(type(new_string))
# Out:
# abcdef
# <class 'str'>

# %%
newest_string = "abc" * 3

print(newest_string)
# Out:
# abcabcabc

# %%
var_one = 1
var_two = 2

print(var_one < 1)
# Out:
# False

# %%
print(var_two >= var_one)
# Out:
# True

# %% [markdown]
# ## if, elif, else:

# %%
temp=36

if temp > 38:
    message = "high!"
elif temp > 35:
    message = "Normal"
else:
    message = "Low"


print(message)
# Out:
# Normal
